# %%
print("Hello, This is week 2")
# Out:
# Hello, This is week 2

# %%
your_name=input("Input your name:")
print(your_name)

# %%
print("I am 4' 15\" tall")
# Out:
# I am 4' 15" tall

# %%
my_sib='''I have 
3 siblings'''
print(my_sib)
print("The interesting fact is that the space between our ages is only 2 years")
formatter="{} {} {} {}"
print("Our ages are", formatter.format(19, 17, 15, 13), "years")
# Out:
# I have
# 3 siblings
# The interesting fact is that the space between our ages is only 2 years
# Our ages are 19 17 15 13 years

# %%
a='''Our second assignment was
          to create a 
                Personal Shopping List'''
print(a)
# Out:
# Our second assignment was
#           to create a
#                 Personal Shopping List

# %%
b=input("Why are you going to do a shopping?")
print(b)

# %%
c=input("How much money do you have?")
print(c)

# %%
print("\t\t\tOur shopping list")
# Out:
# 			Our shopping list

# %%
formatter="{}"
print("carrot",formatter.format(5), "kilos")
# Out:
# carrot: 5 kilos

# %%
vegetables="\nonions\npotatoes\ntomatoes\ncucumbers"
print(vegetables)
# Out:
# onion
# potato
# tomato
# cucumber

# %%
fruits="\nbananas\napples\nstrawbberies\ndates\nkiwis"
print(fruits)
# Out:
# bananas
# apples
# strawbberies
# dates
# kiwis

# %%
other_products="\nmilk\nmeat\nolive oil\nchocolate\nbiscuits\ndesserts\ndrinks\nbread"
print(other_products)
# Out:
# milk
# meat
# olive oil
# chocolate
# biscuits
# desserts
# drinks
# bread
