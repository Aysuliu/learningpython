# %%
usernames=["Aysulu", "Aysanem", "Ulzada", "Aydana", "Ayzada", "admin"]
for name in usernames:
    if name=="admin":
        print("Hello, Admin. Would you like to see a status report?")

    else:
        print(f"Hello, {name}, Thank you for logging in again.")
# Out:
# Hello, Aysulu, Thank you for logging in again.
# Hello, Aysanem, Thank you for logging in again.
# Hello, Ulzada, Thank you for logging in again.
# Hello, Aydana, Thank you for logging in again.
# Hello, Ayzada, Thank you for logging in again.
# Hello, Admin. Would you like to see a status report?
